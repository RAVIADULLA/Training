# %%
spark

# %%
storage_account = 'ssadcloudmainazdl'
storage_container = 'processed'
movies_storage_filepath = 'output-from-dataflow-movies/**'
storage_account_access_key = '<<KEY_FROM_AZURE_DATA_LAKE>>'

# %%
spark.conf.set(
    f"fs.azure.account.key.{storage_account}.dfs.core.windows.net",f"{storage_account_access_key}"
    )

# %%
movies_storage_path = f"abfss://{storage_container}@{storage_account}.dfs.core.windows.net/{movies_storage_filepath}"

# %%
moviesdf = spark.read.parquet(movies_storage_path)

# %%
display(moviesdf)

# %%
moviesdf.createOrReplaceTempView("moviesView")

# %%
spark.sql("select * from moviesView").show()

# %% [markdown]
# ### 1. Lists the contents of a directory

# %%
dbutils.fs.ls('/')

# %%
dbutils.fs.ls('/FileStore')

# %%
dbutils.fs.ls('/FileStore/shared_uploads/')

# %%
display(dbutils.fs.ls('/FileStore/shared_uploads/iriscloudone@outlook.com/'))

# %%
#dbfs:/FileStore/shared_uploads/iriscloudone@outlook.com/dep.csv
display(dbutils.fs.ls('/FileStore/shared_uploads/iriscloudone@outlook.com/dep.csv'))

# %%
display(dbutils.fs.ls('/FileStore/shared_uploads/iriscloudone@outlook.com/'))

# %%
display(dbutils.fs.ls('/FileStore/tables/emp.csv'))

# %% [markdown]
# ### 2. Create Directories

# %%
display(dbutils.fs.ls('/'))

# %%
display(dbutils.fs.mkdirs('/mydir/'))

# %%
display(dbutils.fs.ls('/'))

# %% [markdown]
# ### 3. Using COPY

# %%
display(dbutils.fs.ls('/mydir'))

# %%
emp_filePath = 'dbfs:/FileStore/shared_uploads/iriscloudone@outlook.com/emp.csv'
dep_filePath = 'dbfs:/FileStore/shared_uploads/iriscloudone@outlook.com/dep.csv'

# %%
dbutils.fs.cp(emp_filePath,'/mydir/')

# %%
dbutils.fs.cp(dep_filePath,'/mydir/')

# %%
display(dbutils.fs.ls('/mydir'))

# %%
mydirempdf = spark.read.csv('dbfs:/mydir/emp.csv',header=True,inferSchema=True)
mydirempdf.show()
mydirempdf.schema

# %%
mydirdepdf = spark.read.csv('dbfs:/mydir/dep.csv',header=True,inferSchema=True)
mydirdepdf.show()
mydirdepdf.schema

# %% [markdown]
# ### 4. Delete the Directory

# %%
display(dbutils.fs.ls('/mydir'))

# %%
display(dbutils.fs.rm('/mydir',True))

# %%
display(dbutils.fs.ls('/mydir'))

# %%
display(dbutils.fs.ls('/'))
